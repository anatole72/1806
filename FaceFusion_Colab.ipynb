# %% [markdown]
# <a href="https://colab.research.google.com/github/anatole72/1806/blob/master/FaceFusion_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facefusion/facefusion.git
# %cd /content/facefusion
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu
# Out:
# fatal: destination path 'facefusion' already exists and is not an empty directory.
# /content/facefusion
# ...

# %%
# ==================== FACEFUSION COLAB - Полная установка ====================

import os

# Клонируем официальный репозиторий
# !git clone https://github.com/facefusion/facefusion.git
# %cd /content/facefusion

# Установка зависимостей
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu

# Скачиваем модели (если нужно)
# !python install.py --onnxruntime default

print("✅ Установка завершена!")
print("📁 Текущая папка:", os.getcwd())
# !ls -la
# Out:
# Cloning into 'facefusion'...
# remote: Enumerating objects: 7266, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 7266 (delta 104), reused 49 (delta 29), pack-reused 7114 (from 3)
# Receiving objects: 100% (7266/7266), 27.76 MiB | 34.84 MiB/s, done.
# Resolving deltas: 100% (4983/4983), done.
# /content/facefusion
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 MB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 103.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 95.2 MB/s eta 0:00:00
# ...

# %%
# Path to the core.py file
file_path = '/content/facefusion/facefusion/uis/layouts/default.py'

# Read the content of the file
with open(file_path, 'r') as file:
    content = file.read()

# Replace the line with the updated version
updated_content = content.replace("ui.launch(show_api = False)", "ui.launch(show_api = False, share=True, enable_queue=True)")

# Write the updated content back to the file
with open(file_path, 'w') as file:
    file.write(updated_content)

# %%
# %cd /content/facefusion

# Переустанавливаем с поддержкой GPU
# !pip uninstall -y onnxruntime onnxruntime-gpu

# Устанавливаем GPU версию
# !pip install onnxruntime-gpu --extra-index-url https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/onnxruntime-cuda-12/pypi/simple/

print("✅ onnxruntime-gpu установлен!")
# Out:
# /content/facefusion
# Found existing installation: onnxruntime 1.24.4
# Uninstalling onnxruntime-1.24.4:
#   Successfully uninstalled onnxruntime-1.24.4
# WARNING: Skipping onnxruntime-gpu as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/onnxruntime-cuda-12/pypi/simple/
# ...
#   Using cached onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 6.3 MB/s eta 0:00:00
# ...
# ✅ onnxruntime-gpu установлен!

# %%
# %cd /content/facefusion

# Правильный запуск FaceFusion
# !python facefusion.py run --execution-providers cuda --open-browser
# Out:
# /content/facefusion
# downloading: 100% 8.00/8.00 [00:00<00:00, 33.8B/s, download_providers=['github', 'huggingface'], file_name=nsfw_1.hash]
# downloading: 100% 8.00/8.00 [00:00<00:00, 35.6B/s, download_providers=['github', 'huggingface'], file_name=nsfw_2.hash]
# downloading: 100% 8.00/8.00 [00:00<00:00, 34.8B/s, download_providers=['github', 'huggingface'], file_name=nsfw_3.hash]
# downloading: 100% 76.7M/76.7M [00:02<00:00, 40.2MB/s, download_providers=['github', 'huggingface'], file_name=nsfw_1.onnx]
# downloading: 100% 21.4M/21.4M [00:00<00:00, 29.7MB/s, download_providers=['github', 'huggingface'], file_name=nsfw_2.onnx]
# downloading: 100% 342M/342M [00:05<00:00, 68.6MB/s, download_providers=['github', 'huggingface'], file_name=nsfw_3.onnx]
# downloading: 100% 8.00/8.00 [00:00<00:00, 35.5B/s, download_providers=['github', 'huggingface'], file_name=fairface.hash]
# ...

# %%
# %cd /content/facefusion

# !python facefusion.py run \
    --execution-providers cuda \
    --ui-layouts default
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
